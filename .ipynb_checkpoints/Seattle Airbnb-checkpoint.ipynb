# %% [markdown]
# #### Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# #### Some settings

# %%
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %% [markdown]
# # Business understanding

# %% [markdown]
# ### Questions that I will answer:
# **1. Which neighborhoods have the most places available on Airbnb in Seattle?**
#     (It's important to know the distribution of accommodation by neighborhood and if there is one that predominates.)
# **2. Which neighborhoods are more expensive to stay?**
#     (It's important to know the impact of the neighborhood in the price.)
# **3. What is the correlation between the characteristics of the hotel, such as beds, accommodation, bathrooms and bedrooms with the price of listing?**
#     (Correlation it's a good way to see the influence of this this numerical variables in price.

# %% [markdown]
# # Data understanding

# %%
df = pd.read_csv('./listings.csv')
df.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
# ...

# %%
df.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %% [markdown]
# # Data preparation

# %%
#Removing string "$" from price and transforming into float
def dollar_price_to_float(dollar_price):
    '''
    Convert a string with $ into a float value.
    Input:
        dollar_price: string with "$"
    Output:
        float_price: float number equivalent of dollar_price
    '''
    dollar_price = dollar_price.replace('$','')
    dollar_price = dollar_price.replace(',','')
    float_price = float(dollar_price)
    return float_price
df['price'] = df['price'].apply(dollar_price_to_float)

# %%
#Creating a new dataframe that will be used to calculate the correlation and cleaning up the rows with NaN  
df_correlation = df[['accommodates','bathrooms','bedrooms','beds','price']]
df_correlation = df_correlation.dropna()

# %%
#Removing string "%" from host_response_rate and transform to float
def response_hate_to_float(percent_rate):
    '''
    Convert a string with % into a float value.
    Input:
        percent_rate: string with "%"
    Output:
        float_rate: float number equivalent of percent_rate
    '''
    percent_rate = str(percent_rate)
    percent_rate = percent_rate.replace('%','')
    float_rate = float(percent_rate)
    return float_rate
df['host_response_rate'] = df['host_response_rate'].apply(response_hate_to_float)

# %%
#Converting the field host_is_superhot to a boolean feature
def string_boolean_to_float(string_value):
    '''
    Convert a string with "f" or "t" into a boolean value with 1 or 0.
    Input:
        string_value: string with "f" or "t"
    Output:
        boolean_value: boolean number equivalent of string_value
    '''
    if (string_value == 'f'):
        return 0
    else:
        return 1
df['host_is_superhost'] = df['host_is_superhost'].apply(string_boolean_to_float)
df['host_has_profile_pic'] = df['host_has_profile_pic'].apply(string_boolean_to_float)
df['host_identity_verified'] = df['host_identity_verified'].apply(string_boolean_to_float)

# %% [markdown]
# # Data modeling

# %% [markdown]
# ### Which neighborhoods have the most places available on Airbnb in Seattle?

# %%
df.groupby('neighbourhood').count()['id'].sort_values(ascending=False).head(5).plot(kind="bar");
plt.title("Count listings by neighbourhood");

# %% [markdown]
# ### Which neighborhoods are more expensive to stay?

# %%
df.groupby('neighbourhood').mean()['price'].sort_values(ascending=False).head(5).plot(kind="bar");
plt.title("Mean price by neighbourhood");

# %% [markdown]
# ### What is the correlation between the characteristics of the hotel, such as beds, accommodation, bathrooms and bedrooms with the price of listing?

# %%
heatmap_df = pd.DataFrame(df_correlation.corr()['price'].sort_values(ascending=False).drop('price'))
sns.heatmap(heatmap_df, annot = True, cmap = 'Reds')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Linear Regression

# %%
df_copy = df[['host_response_rate'
              ,'host_is_superhost'
              ,'host_total_listings_count'
              ,'host_has_profile_pic'
              ,'host_identity_verified'
              ,'accommodates'
              ,'bathrooms'
              ,'bedrooms'
              ,'beds'
              ,'guests_included'
              ,'number_of_reviews'
              ,'review_scores_rating'
              ,'reviews_per_month'
              ,'price']]
df_copy = df_copy.dropna()
X = df_copy.drop('price',axis=1)
y = df_copy['price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state=42)
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print('r2_score in test set: ',r2_score(y_test, y_pred))
y_pred = model.predict(X_train)
print('r2_score in train set: ',r2_score(y_train, y_pred))
# Out:
# r2_score in test set:  0.5268111345015327
# r2_score in train set:  0.5134016082674635

# %%
df_coef = pd.DataFrame(list(zip(X.columns, model.coef_)), columns=['feature', 'coef'])

# %%
print(df_coef)
# Out:
#                       feature        coef
# 0          host_response_rate   -0.270118
# 1           host_is_superhost   16.916577
# 2   host_total_listings_count    0.112893
# 3        host_has_profile_pic -113.823358
# 4      host_identity_verified    0.588397
# 5                accommodates   16.444595
# 6                   bathrooms   23.616263
# 7                    bedrooms   18.385626
# 8                        beds   -1.705209
# 9             guests_included    6.877055
# 10          number_of_reviews   -0.035591
# 11       review_scores_rating    0.607460
# 12          reviews_per_month   -4.160203

# %% [markdown]
# # Results evaluation
#
# As you can see, here is a great variation in the price of accommodation by neighborhood, showing that it is a relevant variable if we wanted to elaborate any model, as well as the characteristics of the accommodation that in themselves present a great correlation with the price.
